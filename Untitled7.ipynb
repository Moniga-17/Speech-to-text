# %%
# prompt: python code to get text to speech as output

# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def text_to_speech(text, language='en'):
    tts = gTTS(text=text, lang=language, slow=False)
    tts.save("speech.mp3")
    return Audio("speech.mp3", autoplay=True)

text_to_speech("hello, this is Moniga")
# Out:
# ...
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install moviepy
import moviepy.editor as mp

# Extract audio from the MP4 file
video = mp.VideoFileClip('/content/WIN_20250106_00_02_34_Pro.mp4')
audio = video.audio
audio.write_audiofile("extracted_audio.wav")

audio_file_path = "extracted_audio.wav"
recognized_text = speech_to_text(audio_file_path)
print(recognized_text)
# Out:
# ...
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':
# MoviePy - Writing audio in extracted_audio.wav
# MoviePy - Done.
# hi everyone I'm Monica
